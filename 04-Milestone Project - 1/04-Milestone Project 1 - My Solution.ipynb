# %%
print(" ___ ___ ___\n|   |   |   |\n|___|___|___|\n|   |   |   |\n|___|___|___|\n|   |   |   |\n|___|___|___|")
# Out:
#  ___ ___ ___
# |   |   |   |
# |___|___|___|
# |   |   |   |
# |___|___|___|
# |   |   |   |
# |___|___|___|

# %%
A1 = "X"
B1 = "*"
C1 = "*"
A2 = "X"
B2 = "*"
C2 = "*"
A3 = "X"
B3 = "*"
C3 = "*"

# %%
def board(player_1=[], player_2=[]):

    if player_1:
        for i in player_1:
            if i == "A1":
                A1 = "*"
            if i 
            
    if player_2:


    return (f" ___ ___ ___ ___\n"
            f"|   | A | B | C |\n"
            f"|___|___|___|___|\n"
            f"| 1 | {A1} | {B1} | {C1} |\n"
            f"|___|___|___|___|\n"
            f"| 2 | {A2} | {B2} | {C2} |\n"
            f"|___|___|___|___|\n"
            f"| 3 | {A3} | {B3} | {C3} |\n"
            f"|___|___|___|___|")

# %%
print(board())
# Out:
#  ___ ___ ___ ___
# |   | A | B | C |
# |___|___|___|___|
# | 1 |   |   |   |
# |___|___|___|___|
# | 2 |   |   |   |
# |___|___|___|___|
# | 3 |   |   |   |
# |___|___|___|___|

# %%
def triple_t():

    print(board())

    positions = ["A1", "A2", "A3", "B1", "B2", "B3", "C1", "C2", "C3"]
    player_1 = []
    player_2 = []

    while len(positions) > 0 :

        if len(player_1) <= len(player_2):
            pos = input(f"Player 1, Choose a position: from {positions}: ")
            if pos in positions:
                player_1.append(pos)
                positions.remove(pos)
        else:
            pos = input(f"Player 2, Choose a position: from {positions}: ")
            if pos in positions:
                player_2.append(pos)
                positions.remove(pos)

        print(board())

    return player_1, player_2

# %%
triple_t()
# Out:
#  ___ ___ ___ ___
# |   | A | B | C |
# |___|___|___|___|
# | 1 |   |   |   |
# |___|___|___|___|
# | 2 |   |   |   |
# |___|___|___|___|
# | 3 |   |   |   |
# |___|___|___|___|
# (['A1', 'A2', 'B2', 'C1', 'C3'], ['A3', 'B1', 'B3', 'C2'])
